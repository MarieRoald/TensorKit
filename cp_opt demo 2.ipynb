# %%
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
from pprint import pprint
import itertools

import cp
import base
import utils
import metrics

# %% [markdown]
# ## Generate random data

# %%
np.random.seed(0)
sizes = [10, 15, 20]
rank = 3

tensor, factors, norms, noise = utils.create_data(sizes, rank, noise_factor=0)

# %% [markdown]
# ## Find decomposition with cp_opt

# %%
cp_factors, result, _, log = cp.cp_opt(tensor, method='cg', rank=4, init='svd', gtol=1e-15)

print(result.message)
print(f'F(x): {result.fun}')
print(f'Number of iterations: {result.nit}')
print(f'Number of function evaluations: {result.nfev}')
#cp_factors, result, = cp.cp_als(tensor, rank=rank, init='svd', convergence_th=1e-15)
# Out:
# Maximum number of iterations has been exceeded.
# F(x): 3.1695081922716244e-15
# Number of iterations: 1000
# Number of function evaluations: 1661

# %%
fig = plt.figure(figsize=(20, 5))
ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(log.loss_values)
ax1.set_title('Loss')
ax1.set_xlabel('Iterations')

ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(log.gradient_values)
ax2.set_title('Gradient magnitude')
ax2.set_xlabel('Iterations')

ax1.set_yscale('log')
ax2.set_yscale('log')

plt.show()

# %% [markdown]
# ## Check how well we recover the true factors

# %%
cp_factors_norm, cp_norms = utils.normalize_factors(cp_factors)
cp_weights = np.prod(np.concatenate(cp_norms), axis=0)

# %%
score, best_permutation = metrics.factor_match_score(factors, cp_factors)

print(f'Factor match score: {score}')
print(f'Best match permutation: {best_permutation}')
# Out:
# Factor match score: 0.999999999980828
# Best match permutation: (1, 0, 2)

# %%
f1, s1, n1 = utils.prepare_for_comparison(factors)
f2, s2, n2 = utils.prepare_for_comparison(utils.permute_factors(best_permutation, cp_factors_norm))

fig, axes = plt.subplots(len(sizes), 2, figsize=(16, 6))
for i in range(len(factors)):
    axes[i][0].plot(f1[i], '-o')
    axes[0][0].set_title('True factors')
    
    axes[i][1].plot(f2[i], '-o')
    axes[0][1].set_title('Estimated factors')

plt.show()
